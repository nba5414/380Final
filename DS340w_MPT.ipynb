# %% [markdown]
# <a href="https://colab.research.google.com/github/nba5414/380Final/blob/main/DS340w_MPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Athors:
# Artemii Polshcha
# Nicholas Allen
#
# Professor:
# Dr. Raahemifar

# %%
# !pip install yfinance

# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import yfinance as yf
from datetime import datetime

# %%
msft = yf.Ticker("MSFT")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-a248867e7cbf> in <cell line: 1>()
# ----> 1 msft = yf.Ticker()
#
# TypeError: Ticker.__init__() missing 1 required positional argument: 'ticker'

# %%
hist = msft.history(period="10y")

# %%
hist.shape
# Out:
# (2517, 7)

# %%
data = yf.download("AMZN AAPL GOOG", start="2014-01-01", end="2024-01-01")[['Adj Close', 'Open']]
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
data
# Out:
# Price                       Adj Close                                Open  \
# Ticker                           AAPL        AMZN        GOOG        AAPL
# Date
# 2014-01-02 00:00:00+00:00   17.253258   19.898500   27.692570   19.845715
# 2014-01-03 00:00:00+00:00   16.874279   19.822001   27.490559   19.745001
# 2014-01-06 00:00:00+00:00   16.966286   19.681499   27.797060   19.194643
# 2014-01-07 00:00:00+00:00   16.844952   19.901501   28.332937   19.440001
# 2014-01-08 00:00:00+00:00   16.951632   20.096001   28.391901   19.243214
# ...                               ...         ...         ...         ...
# 2023-12-22 00:00:00+00:00  192.868149  153.419998  142.557770  195.179993
# 2023-12-26 00:00:00+00:00  192.320221  153.410004  142.657669  193.610001
# 2023-12-27 00:00:00+00:00  192.419830  153.339996  141.279236  192.490005
# 2023-12-28 00:00:00+00:00  192.848206  153.380005  141.119415  194.139999
# 2023-12-29 00:00:00+00:00  191.802185  151.940002  140.769806  193.899994
#
# ...
